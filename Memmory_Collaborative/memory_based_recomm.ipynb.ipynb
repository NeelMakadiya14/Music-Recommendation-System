# %%
import random
import time
import math
import sys
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
#Some Utility functions for accessing the files from MSD

def song_to_count(if_str):
    stc = dict()
    with open(if_str, "r") as f:
        for line in f:
            _, song, _ = line.strip().split('\t')
            if song in stc:
                stc[song] += 1
            else:
                stc[song] = 1
    return stc


def user_to_count(if_str):
    utc = dict()
    with open(if_str, "r") as f:
        for line in f:
            user, _, _ = line.strip().split('\t')
            if user in utc:
                utc[user] += 1
            else:
                utc[user] = 1
    return utc


def sort_dict_dec(d):
    return sorted(d.keys(), key=lambda s: d[s], reverse=True)


def song_to_users(if_str, set_users=None, ratio=1.0):
    stu = dict()
    with open(if_str, "r") as f:
        for line in f:
            if random.random() < ratio:
                user, song, _ = line.strip().split('\t')
                if not set_users or user in set_users:
                    if song in stu:
                        stu[song].add(user)
                    else:
                        stu[song] = set([user])
    return stu


def user_to_songs(if_str):
    uts = dict()
    with open(if_str, "r") as f:
        for line in f:
            user, song, _ = line.strip().split('\t')
            if user in uts:
                uts[user].add(song)
            else:
                uts[user] = set([song])
    return uts


def load_unique_tracks(if_str):
    ut = []
    with open(if_str, "r") as f:
        for line in f:
            a_id, s_id, a, s = line.strip().split('<SEP>')
            ut.append((a_id, s_id, a, s))
    return ut


def load_users(if_str):
    with open(if_str, "r") as f:
        u = map(lambda line: line.strip(), f.readlines())
    return u


def song_to_idx(if_str):
    with open(if_str, "r") as f:
         sti = dict(map(lambda line: line.strip().split(' '), f.readlines()))
    return sti


def unique_users(if_str):
    u = set()
    with open(if_str, "r") as f:
        for line in f:
            user, _,_ = line.strip().split('\t')
            if user not in u:
                u.add(user)
    return u

def save_recommendations(r, songs_file, ofile):
    print("Loading song indices from " + songs_file)
    s2i = song_to_idx(songs_file)
    print("Saving recommendations")
    f = open(ofile, "w")
    for r_songs in r:
        indices = map(lambda s: s2i[s], r_songs)
        f.write(" ".join(indices)+"\n")
    f.close()
    print("Ok.")

def songToSongName():
    pass

# %%
#Utility functions for evaluation

def sort_dict_dec_util(d):
    sorted_keys = sorted(d.keys(), key=lambda s: len(d[s]), reverse=True)
    sorted_dict = {}
    for i in range(0,len(d)):
        sorted_dict[sorted_keys[i]] = d[sorted_keys[i]]
    return sorted_dict

def user_to_songs_util(if_str):
    uts = dict()
    with open(if_str, "r") as f:
        for line in f:
            user, song, _ = line.strip().split('\t')
            if user in uts:
                uts[user].add(song)
            else:
                uts[user] = set([song])
    return sort_dict_dec_util(uts)

def AP_mod(l_rec, user_given_songs, tau):

    np = len(user_given_songs)
    #print "np:", np
    nc = 0.0
    ap = 0.0
    for j, s in enumerate(l_rec):
        if s in user_given_songs:
            # print "s in sMu"
            nc += 1.0
            ap += nc/(j+1)
    ap /= min(np, tau)
    return ap

def mAP_mod(first_500, l_rec_songs, u2s_testing, tau):
    mapr = 0
    n_users = len(first_500)
    # for i, l_rec in enumerate(l_rec_songs):
    #     if not first_500[i] in u2s_testing:
    #         continue
    #     mapr += AP(l_rec, u2s_testing[first_500[i]], tau)
    # return mapr/n_users

    for user in first_500:
        if not user in u2s_testing:
            continue
        mapr += AP_mod(l_rec_songs[user], u2s_testing[user], tau)
    return mapr/n_users

# %%
#Predictor, Recommendors and mAP

def AP(l_rec, sMu, tau):

    np = len(sMu)
    #print "np:", np
    nc = 0.0
    mapr_user = 0.0
    for j, s in enumerate(l_rec):
        if j >= tau:
            break
        if s in sMu:
            # print "s in sMu"
            nc += 1.0
            mapr_user += nc/(j+1)
    mapr_user /= min(np, tau)
    return mapr_user


def mAP(l_users, l_rec_songs, u2s, tau):
    mapr = 0
    n_users = len(l_users)
    for i, l_rec in enumerate(l_rec_songs):
        if not l_users[i] in u2s:
            continue
        mapr += AP(l_rec, u2s[l_users[i]], tau)
    return mapr/n_users



#Predictors
class Pred:

    def __init__(self):
        pass

    def Score(self, user_songs,  all_songs):
        return {}

#ItemBased Predictor
class PredSI(Pred):

    def __init__(self, _s2u_tr, _A=0, _Q=1):
        Pred.__init__(self)
        self.s2u_tr = _s2u_tr
        self.Q = _Q
        self.A = _A

    def printAandQ(self):
        print("PredSI(A=%f,Q=%f)" % (self.A, self.Q))

    def Match(self, song1, song2):
        l1 = len(self.s2u_tr[song1])
        l2 = len(self.s2u_tr[song2])
        up = float(len(self.s2u_tr[song1] & self.s2u_tr[song2]))
        if up > 0:
            dn = math.pow(l1, self.A)*math.pow(l2, (1.0-self.A))
            return up/dn
        return 0.0

    def Score(self, user_songs,  all_songs):
        s_scores = {}
        for s in all_songs:
            s_scores[s] = 0.0
            if not (s in self.s2u_tr):
                continue
            for u_song in user_songs:
                if not (u_song in self.s2u_tr):
                    continue
                s_match = self.Match(s, u_song)
                s_scores[s] += math.pow(s_match, self.Q)
        return s_scores

#UserBased SImilarity Model
class PredSU(Pred):     
    def __init__(self, _u2s_tr, _A=0, _Q=1):
        Pred.__init__(self)
        self.u2s_tr = _u2s_tr
        self.Q = _Q
        self.A = _A

    def printAandQ(self):
        print("PredSU(A=%f,Q=%f)" % (self.A, self.Q),)

    def Score(self, user1_songs,  all_songs):
        s_scores = {}
        for u_tr in self.u2s_tr:
            if not u_tr in self.u2s_tr:
                continue
            user2_songs = self.u2s_tr[u_tr]
            w = float(len(user2_songs & user1_songs))
            if w > 0:
                l1 = len(user1_songs)
                l2 = len(user2_songs)
                w /= (math.pow(l1, self.A)*(math.pow(l2, (1.0-self.A))))
                w = math.pow(w, self.Q)
            for s in user2_songs:
                if s in s_scores:
                    s_scores[s] += w
                else:
                    s_scores[s] = w
        return s_scores


def fl():
    sys.stdout.flush()
#Recommenders
class Reco:
    def __init__(self, _all_songs):
        self.predictors = []
        self.all_songs = _all_songs
        self.tau = 50

    def Add(self, p):
        self.predictors.append(p)

#Recomender to Randomly recomend songs from the selected list.
class SReco(Reco):

    def __init__(self, _all_songs):
        Reco.__init__(self, _all_songs)
        self.Gamma = []

    def RandomIndex(self, n, distr):
        r = random.random()
        for i in range(n):
            if r < distr[i]:
                return i
            r -= distr[i]
        return 0

    def RandomRec(self, songs_sorted, distr):
        nPreds = len(self.predictors)
        r = []
        ii = [0]*nPreds
        while len(r) < self.tau:
            pi = self.RandomIndex(nPreds, distr)
            s = songs_sorted[pi][ii[pi]]
            if not s in r:
                r.append(s)
            ii[pi] += 1
        return r


    def RecommendToUser(self, user, u2s_v):
        songs_sorted = []
        for p in self.predictors:
            ssongs = []
            if user in u2s_v:
                ssongs = sort_dict_dec(
                    p.Score(u2s_v[user], self.all_songs))
            else:
                ssongs = list(self.all_songs)

            cleaned_songs = []
            for x in ssongs:
                if len(cleaned_songs) >= self.tau:
                    break
                if x not in u2s_v[user]:
                    cleaned_songs.append(x)

            songs_sorted += [cleaned_songs]

        return self.RandomRec(songs_sorted, self.Gamma)

    def RecommendToUsers(self, l_users, u2s_v):
        sti = time.time()
        rec4users = []
        for i, u in enumerate(l_users):
            if not (i+1) % 10:
                if u in u2s_v:
                    print("%d] %s w/ %d songs " %
                          (i+1, l_users[i], len(u2s_v[u])))
                else:
                    print("%d] %s w/ 0 songs" % (i+1, l_users[i]))
            fl()
            rec4users.append(self.RecommendToUser(u, u2s_v))
            cti = time.time()-sti
            if not (i+1) % 10:
                print(" tot secs: %f (%f)" % (cti, cti/(i+1)))
                fl()
        return rec4users

# %%
#Storing Testing and Training Data
u2s_testing = user_to_songs_util('year1_test_triplets_hidden.txt')
u2s_training = user_to_songs_util('year1_test_triplets_visible.txt')

users = u2s_training.keys()
users = list(users)
first_500 = users[:500]

# %% [markdown]
# Song-Based Recommender System

# %%
sys.stdout.flush()

# TRIPLETS
f_tr = "year1_test_triplets_hidden.txt"
f_tev = "year1_test_triplets_visible.txt"

print('loading users in %s'%"kaggle_users.txt")
sys.stdout.flush()
users_v = list(load_users("kaggle_users.txt"))

print('default ordering by popularity')
sys.stdout.flush()
songs_ordered=sort_dict_dec(song_to_count(f_tr))

print("loading unique users indexes")
uu = unique_users(f_tr)
u2i = {}
for i,u in enumerate(uu):
    u2i[u]=i

print('song to users on %s'%f_tr)
s2u_tr=song_to_users(f_tr)

print("converting users to indices")
for s in s2u_tr:
    s_set = set()
    for u in s2u_tr[s]:
        s_set.add(u2i[u])
    s2u_tr[s]=s_set

del u2i

print('user to songs on %s'%f_tev) 
u2s_ev=user_to_songs(f_tev)     
u2s_tr=user_to_songs(f_tr)     

print('Creating predictor..')

alpha = 0.15
q_value = 3
NumOfRecommendations = 30

pr=PredSI(s2u_tr, alpha, q_value)       #Song Based Prediction
print('Item-Item Similarity Based Predictor Created.')


print('Creating recommender..')
cp = SReco(songs_ordered)
cp.Add(pr)
cp.Gamma=[1.0]
cp.tau = NumOfRecommendations
r=cp.RecommendToUsers(users[:100],u2s_ev)
# Out:
# loading users in kaggle_users.txt
# default ordering by popularity
# loading unique users indexes
# song to users on year1_test_triplets_hidden.txt
# converting users to indices
# user to songs on year1_test_triplets_visible.txt
# Creating predictor..
# Item-Item Similarity Based Predictor Created.
# Creating recommender..
# 10] 992fea335363e87217e1b052fd7380b3fd7e35b4 w/ 51 songs
#  tot secs: 272.768773 (27.276877)
# 20] 7a1da2cfab87398a137441a85aee84793a376302 w/ 49 songs
#  tot secs: 495.571044 (24.778552)
# 30] 597c85c79b8dde655ec3fb8a7c41e3427d7f716f w/ 48 songs
#  tot secs: 727.916728 (24.263891)
# 40] dfadfaa39598cf760125439346d903ea0467e7fa w/ 48 songs
#  tot secs: 965.832902 (24.145823)
# 50] 3233c598c50f0ddbd351504e773cd51de79691db w/ 47 songs
#  tot secs: 1217.400358 (24.348007)
# 60] 970fafbf218e788e97784de3d681f7486fe5376a w/ 47 songs
#  tot secs: 1439.621354 (23.993689)
# 70] 126a1a844437af98ac07350e1e3dbec9681d5be4 w/ 46 songs
#  tot secs: 1741.685360 (24.881219)
# 80] c51db436e58a0d44d8d6c171182254eaf0d136a4 w/ 46 songs
#  tot secs: 2042.084330 (25.526054)
# 90] 03c89ca804a4c80a2ec64504ff2cdacc47d97d45 w/ 45 songs
#  tot secs: 2350.825000 (26.120278)
# 100] 2d50e29337f17ef1521e32d2310acf3be51984b6 w/ 45 songs
#  tot secs: 2566.778130 (25.667781)
# 100
# Loading song indices from kaggle_songs.txt
# Saving recommendations
# Ok.

# %%
l_rec_songs_dic = dict()
for i,rlist in enumerate(r):
    l_rec_songs_dic[users[i]] = rlist

# %%
temp = pd.read_csv(
    'unique_tracks.txt', sep='<SEP>', header=None)
temp.columns = ['track_id', 'song_id', 'artist_name', 'song_title']

song_id_to_title = {}

for index, row in temp.iterrows():
  song_id_to_title[row['song_id']] = row['song_title']
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_15420/289161521.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   temp = pd.read_csv(

# %%
#3 Recommendations for all the users using SongBased Similarity
for user in l_rec_songs_dic:
    print(f'Songs for User[{user}]:')
    for rsong in l_rec_songs_dic[user][:3]:
        print(song_id_to_title[rsong])
# Out:
# Songs for User[7d90be8dfdbde170f036ce8a4b915440137cb11c]:
# One More Reason
# Ne-Ne Na-Na Na-Na Nu-Nu
# Polish Girls
# Songs for User[016a24e91a72c159a5048ab1b9b2ba5ce761b526]:
# Chic tu chic
# The Black Crow Knows
# Black Cherry
# Songs for User[03ad93fdb01506ce205f4708decf8e4b1ae90fff]:
# Due Mondi
# Quello Che Le Donne Non Dicono
# Gli Angeli (Italian Mainstream Mix)
# Songs for User[0f8308935bcbb9a1e04ebb7c4d41c037e5f23b90]:
# Slow Crows Over
# Houria
# Real Life (feat. B Real)
# Songs for User[2e424b28bff1f62a2dae22a918f09f9c30c06d1b]:
# Thousand Mile Wish
# A Little Miracle
# Spank Me Baby
# Songs for User[d30e18323f15426c3cdc8585252ed34459916f51]:
# Coldest Night Of The Year
# If She's Near
# Room 108
# Songs for User[316110734d8da7478cc33237458814f770a9eb7a]:
# Promise (featuring Chris Cornell)
# Please Play This Song On The Radio
# You Will Lose Faith
# Songs for User[7e27789eae69bc946c51833c0b833a49c58ed9ed]:
# Physical Overdrive
# On A Saturday Nite
# Drip
# Songs for User[9769ebffc543fa42b58daf6f52f8816abf5f408e]:
# Te Hablaré
# Como Se O Mar
# Caneco 70
# Songs for User[992fea335363e87217e1b052fd7380b3fd7e35b4]:
# Bright Shiny Lights
# No Woman No Cry
# Wooden Arms
# Songs for User[e08848e92427e9ef8add59a1264c484e1078d5a5]:
# Bible_ Candle and Skull
# O Lee O
# Skinheads A Bash Them
# Songs for User[e99ef008f893efd071a7a77be6f1e8d23b962278]:
# Broken Compass (Album)
# Leave Your Body
# Kill The Man
# Songs for User[1fb619ced83fb4f92d4098709d7331b30e5e691c]:
# Lay Back In The Arms Of Someone
# I Couldn't Believe
# Turn On The World
# Songs for User[9b0f827c8bad0cf089b0d778307e1b390f463730]:
# Give 'Em The Money (live)
# Playing The Blame Game
# Underdog (Acoustic Version)
# Songs for User[ad4b2717e89766b66b96fe52a38736116e315874]:
# Brick By Brick
# Rarefied
# Walking In L.A. (2002 Digital Remaster)
# Songs for User[b7bc5c9ea762079424d014c1b4e05e1d65d68861]:
# Apocalipsis
# Bitter (LP Version)
# Flying High
# Songs for User[b976263ea6b444c431759549a75b3650c66183a6]:
# Press 2
# Les grandes questions
# Will It Be This Way Forever?
# Songs for User[ca885bed5d391ccc0fda84e8eb4441e005f68bcd]:
# Top Expert
# They Tell Me
# Enough
# Songs for User[6a41b6a2e27eff73509684bdfa13271b571e2e64]:
# Say A Prayer
# They Didn't Know
# A Living Testimony (LP Version)
# Songs for User[7a1da2cfab87398a137441a85aee84793a376302]:
# Vivre Ou Survivre
# Love Gun
# Go For You
# Songs for User[cdf02034d8a63dd8f4b4c22a5e7b225a37bdb844]:
# The Bleeding
# Country Mike's Theme (Digitally Remastered 99)
# Cottonwool
# Songs for User[fd94f121ddfa8521f2348cb9863f0a7b475b7690]:
# Every Lasting Light
# Too Afraid To Love
# So Quiet
# Songs for User[0c210254fc2eaf598f3a1b68212d4202d91a9935]:
# Please Just Take These Photos From My Hands
# Set Down Your Glass
# City
# Songs for User[0f006f78b80e7a1f2767c8bdeecf9c81f2fdc78c]:
# Mock The Cross
# Summer Dress
# Earthrot
# Songs for User[21a96fddf16490d907e44d0dfa11981ede0d96e9]:
# Make & Break Harbour
# The Wreck of the Athens Queen
# No Woman No Cry
# Songs for User[2cc9422e11d2c7e3b0ab5aca3fa22308995ff15d]:
# Hanging On
# Kiss You
# Baker's Dozen
# Songs for User[4759c3e074d8a6d1caeab6ca4a88c06384d42748]:
# A Hero Loses Everyday
# Exciting Forms of Destruction
# The World I Know (LP Version)
# Songs for User[531d1d0b66781028d346e0f0859713b982240382]:
# Washed Away
# A Toutes Les Fois (2004 Digital Remaster)
# P'tit homme
# Songs for User[5557cc213a706529adba8419eee285cfe9e43c24]:
# Ommadawn (excerpt)
# Aurora
# Todo por la patria
# Songs for User[597c85c79b8dde655ec3fb8a7c41e3427d7f716f]:
# Baila Girl_ Todo Hombre Llorando Por Ti
# Boyz-N-The-Hood (Explicit)
# Now & Forever
# Songs for User[5b3b7cd00e95e2680fac770b7e18c070bf02e527]:
# Love Vista (featuring Clementine) (Remix by Larry Heard "Mr. Fingers")
# Bed (Instrumental)
# Haunted Out-take
# Songs for User[5cebb084cfddab0dfd1e5ab5c3184b2e0c560786]:
# Shri Ram Jai Ram
# After All
# Straight Thin Line
# Songs for User[5dd9ca919c054bfa1deb7bb6945e85c153803d4c]:
# What Cha Know About This
# Fresh Off The Boat
# Won't Let You Fall
# Songs for User[6e319c81e97184f63ab101e94b6d3222d672d5ff]:
# I Think I'll Be Ok
# Time And A Half
# The First Of The Century
# Songs for User[8a463b7fe927c959e551be2efec5a7e1e0064929]:
# Live A Lie
# Two Sides ([Witchman's accelerator mix])
# Colors
# Songs for User[9cf0817fa7aaeb64882d7e51ba76be667c8d072c]:
# Flowin' Prose (2009 Digital Remaster)
# La intifada
# Last One
# Songs for User[9daa6c7bda5ddabd68d04e678b3e52c30b9ab843]:
# Tomasovi
# Deadtime
# Senor Limpio
# Songs for User[cf2c73076560378d178b35264851b6999bdc9579]:
# Township Funk (Crazy P Remix)
# Dial L For Love
# Inspirations (Innocent Sorcerers Remix)
# Songs for User[d49babd1945ee325cdd3aaf152d6c76fccc0c04b]:
# When The Ship Comes In
# What A Shame_ What A Shame
# Danny Boy (Fiddle Air)
# Songs for User[dfadfaa39598cf760125439346d903ea0467e7fa]:
# Hello_ Helicopter!
# Memory Daydreams Lapses
# Head
# Songs for User[ecd8e3aaf27af93873acff818f531f5c5d037dcb]:
# Brackett_ WI
# Die
# Year of the Suckerpunch
# Songs for User[030915d79bddd3062aa433513ad36a943ab4152f]:
# The Last Call
# The Whores Hustle And The Hustlers Whore
# I'm For You
# Songs for User[052213105f0428f006119159553425c07c239c97]:
# Too Hip_ Gotta To
# Maggie's Farm (From the album Itchy Feet)
# Trust Me
# Songs for User[1ba3904f06a1b49da7ec7f016b42c983042fd321]:
# The Beach
# Why
# The Christmas Song (Chestnuts Roasting On An Open Fire)
# Songs for User[254e95345a32c795b049a8d7e9e6a11cfcfef42d]:
# Hule Lam
# God Is God
# Jardin De Cecile
# Songs for User[26b5dfef4cb37db6510a1d77076584811980092f]:
# Bruised Water (Original Radio Edit)
# We Belong
# Asarja
# Songs for User[284124ef289e16c8746b081e92fec46d9eed5e78]:
# A Little More Cream_ Please
# Elvis Talking (You Think It's Over But It's Not)
# You Lay the Dust (Feat Jeff Pevar)
# Songs for User[2bf9c6c4c5189bd941d16116bf818f6c59d7f741]:
# Blunt Picket Fence
# Yflmd
# Brand New Dub
# Songs for User[31a5f05c993b55420ff5b207fe64b193599215d3]:
# Human Jerky And The Active Cultures
# Colostomy Jigsaw Puzzle
# Bathing In A Grease Disposal Unit
# Songs for User[3233c598c50f0ddbd351504e773cd51de79691db]:
# Lord Of Eternity
# Blow Away (Explicit Album Version)
# Ss-3
# Songs for User[3f3984c156def23041b2bd2bfb8884f57f5f2d66]:
# Where More Gifted People Cracked
# Like A Rocket (LP Version)
# Two Blue Lights
# Songs for User[4288f4be2b04525b62ab8ba0fd6dd93f32f140e9]:
# Princess
# Since You Were Gone
# France Télécom
# Songs for User[5a1a71a60eb86d499a9a3a885d375e66fab0338a]:
# Hold up
# Summer Smoke
# Once again
# Songs for User[5e9d9185ca70601ff94ed404d3dc92bee6ec0e01]:
# Shyness
# The Fall of Math
# Hole
# Songs for User[7a9bd2500f3baa32501b1c9ea9220b193f28b1fd]:
# Cautious
# I'm Not A Kid Anymore
# Duende (live)
# Songs for User[7b18741a2c0e8e2c9c09d2fa7b7d89c8dcb61ed6]:
# I Want A Day (Album Version)
# Bomb the Music Industry! (and Action Action) (and Refused) (and Born Against) Are Fucking Dead
# Ready...Set...No!!!
# Songs for User[82d5c2935d6c31c3042630a23ff1dd51fa2e952c]:
# Dressed Up
# Not Giving In
# The Stairs Are Like An Avalanche
# Songs for User[8c2fae6b21964abbf0e873a8a300410390c081a9]:
# Skylight
# Peacock Stomp
# The Slide (On and On Mix)
# Songs for User[93e00920cb43b2f43c3eef4026597817fa11097d]:
# Manhã
# Eu Não Paro
# Milhares De Sambas
# Songs for User[970fafbf218e788e97784de3d681f7486fe5376a]:
# My Lucky Day
# Saturn Girl (Remastered Album Version)
# You Make Me Want To Be A Man
# Songs for User[9edb7c549e06471e8da43bf484120044341f7bd4]:
# Coma (LP Version)
# Kid Charlemagne
# Wonderful (LP Version)
# Songs for User[a0f6b8e2976781c862094eac5c3dfe65c1044908]:
# You've Got Your Troubles
# Copper Sunset
# Wondering
# Songs for User[b874455ac93a9d7128a096d45e8dd8ed75298a1f]:
# Edge Of The Blade
# The Melee
# Undying Love
# Songs for User[c285a495ee23d5939f4cf3ac718cc1e3546130f3]:
# Tløn
# Czarne Slowa (Black Words)
# High And Dry
# Songs for User[ca94838fb75b5a9403790364bd8a56e8df8b547a]:
# Not Too Bad
# Song Of Life (LP Version)
# The Electric Horse Garden
# Songs for User[d02a3c6c8dc8fc11c512024253a97693e544d90c]:
# A Veces Vuelvo
# Abstracto
# Batalla
# Songs for User[d5eb93b6ba887c9828abe9cbb7e02fa7f9cf2b08]:
# Las Madres Del Amor
# Manchmal Möchte Ich Schon Mit Dir... (Single Version) (Feat. Chriss TUXI)
# Sing For Me
# Songs for User[e48ec63ed90a119eafe5338b18850ad2502e6910]:
# I'm No Good
# On Savait (Devenir Grand)
# Put Your Hand In The Hand (Single/LP Version)
# Songs for User[e8b69fea692deaa7ad925ba52fbcabbc4b4ed961]:
# If You Go Away
# Don't Cry For Me Argentina
# You Know What
# Songs for User[126a1a844437af98ac07350e1e3dbec9681d5be4]:
# Hé Doe Maar Mee (Karaoke)
# Give It All Away
# Child Of The King (Album Version)
# Songs for User[13cee37ea2e198ce8354a962b118c1770db351d6]:
# Soft As Snow (But Warm Inside)
# In the Attic
# Sing
# Songs for User[1883628f31fcf5793dbc0d6d6a97de6d7025b29f]:
# Keep On Trying
# Time is Right
# La Fièvre
# Songs for User[29b9a2bbe03bbc749926eb27374fd371a4504cda]:
# Behind The Sun (2003 Digital Remaster)
# Fathers From The Sun
# Under Moonshine
# Songs for User[44a7e35f9096a1b089d6c4a9824026792ad22ab7]:
# Frantic
# Scrape And A Pull
# My Love I Love
# Songs for User[6f0b83b30aa02aa6e211e7c26b6e5f3b69eed441]:
# Soñando En Ti
# I Feel Love
# Crack teeth
# Songs for User[8c8b8f3f729f8a95b5ad27bebd8ef63fc69fa92f]:
# Brennero
# Esperanto
# Murder Of...
# Songs for User[a4892375ecd9d837c01ae56f65c7e0c971cf6404]:
# Night Of Joy
# No Way
# Little Fury
# Songs for User[bf628d66bd65a4287683183a1f4d55a5df722a2a]:
# The Lover
# You're Driving Me Insane
# Prognosis (bonustrack)
# Songs for User[c4adbfad63abf742ce4e7831626c0dffbba594c1]:
# March Of The Celts
# Boadicea
# Epona
# Songs for User[c51db436e58a0d44d8d6c171182254eaf0d136a4]:
# The One (I'm Fighting For)
# Love You Tomorrow
# Dare To Believe
# Songs for User[c75cf74cab428a4cba9b8679a5c0d2843caaf928]:
# Pireotaki
# Hello L-O-V-E (LP Version)
# He Was A Friend Of Mine
# Songs for User[cb5a3fd164ba01767a35a4311baaf5de47aa815b]:
# Waarom Huil Je
# What A Wonderful World
# Todo Lo Que Tengo
# Songs for User[cf9fdf97c554f55a5ee15573a8bc9ca9f93f8487]:
# De Boca En Boca
# Johnny B. Goode
# Human Error
# Songs for User[cff21116daa6af7719ed41e4b540feeaf5f31803]:
# Undo
# Dog Days Are Over (Radio Edit)
# Secrets
# Songs for User[dcc2873cbb96146e4187c2f7e785d690ecf42b65]:
# Let's Party
# Wildflower
# Too Late For A Change
# Songs for User[ef9f2f97aa9f72d4c18609e414a9077234c27119]:
# Anjunabeach
# Yours To Hold (Album Version)
# The Booty Pop Phantom Anthem
# Songs for User[f148be1d392e400016ec4ef3610259d0c5851c5e]:
# The Forest
# I still Do
# Shreveport To New Orleans
# Songs for User[f3dbd374830a4ee7cca9f967a07b5bc91b3b5c52]:
# The Biggest Lie I Ever Told
# Exaltation
# Sea to Sea
# Songs for User[01a85f046df67f633f93584e4304c2ba9ed69717]:
# My Hi Tops
# Black Cat_ White Cat
# Ms. Lollipop
# Songs for User[03c89ca804a4c80a2ec64504ff2cdacc47d97d45]:
# Big Lights
# Heartstrings
# Through The Window Of A Train
# Songs for User[076f4ffd2d560d0c4c77049587d4b9a0a9f9d566]:
# Let's Go Home
# Strobelite Honey
# Smoke Stack (Alternate Take) (Rudy Van Gelder 24Bit Mastering) (2003 Digital Remaster)
# Songs for User[0b505a2b01ab9f3aca17e6f56d78739a045482e0]:
# Pink Noise
# 3000 Miles Away
# I'm Cool
# Songs for User[0ea17495115c4796365f24c15215da79749c6478]:
# Booyaka 619
# A Mighty Fortress
# Doom Walker
# Songs for User[208570bd10225df3b6d8320f80a4a6f4640f859e]:
# Home again (live)
# Emmanuel
# Spirit Of The Sea
# Songs for User[2457a1423fbc83fd39f4dfcbcab73dc5a90ab7c5]:
# Dans vanavond met mij
# Maybe Maybe (live radio session)
# Our Day's Coming
# Songs for User[25ad9ea0366e4e39ac188266a73e4e643538108d]:
# La Zamba Perdida
# Zamba Del Carnaval
# Cometer suicidio
# Songs for User[2603699970dd851de605969efe7692025d781451]:
# She Ain't Got No Legs
# Perjantaina (Album Version)
# Last Night The Moon Came
# Songs for User[2bcfb4744620a204cd7a1c562f58336846b17c5e]:
# Fathers and Sons
# So Let Go
# Fathers & Sons
# Songs for User[2cd5d5b6e63be5eb0b0236a3abe0507edf0f6570]:
# Believin´
# Spite Suicide
# Smoke On The Water
# Songs for User[2d50e29337f17ef1521e32d2310acf3be51984b6]:
# A Death Waltz
# American Idol
# Rose's Turn

# %%
mAP_SongBased = mAP_mod(users[:100],l_rec_songs_dic,u2s_testing,30)

# %%
print(mAP_SongBased)
# Out:
# 0.041726901853522964

# %% [markdown]
# User-Based Model

# %%
sys.stdout.flush()

# TRIPLETS
f_tr = "year1_test_triplets_hidden.txt"
f_tev = "year1_test_triplets_visible.txt"

print('loading users in %s' % "kaggle_users.txt")
sys.stdout.flush()
users_v = list(load_users("kaggle_users.txt"))

print('default ordering by popularity')
sys.stdout.flush()
songs_ordered = sort_dict_dec(song_to_count(f_tr))

print("loading unique users indexes")
uu = unique_users(f_tr)
u2i = {}
for i, u in enumerate(uu):
    u2i[u] = i

print('song to users on %s' % f_tr)
s2u_tr = song_to_users(f_tr)

print("converting users to indices")
for s in s2u_tr:
    s_set = set()
    for u in s2u_tr[s]:
        s_set.add(u2i[u])
    s2u_tr[s] = s_set

del u2i

print('user to songs on %s' % f_tev)
u2s_ev = user_to_songs(f_tev)
u2s_tr = user_to_songs(f_tr)

print('Creating predictor..')

alpha = 0.15
q_value = 3
NumOfRecommendations = 30

UB_pred = PredSU(u2s_training, alpha, q_value)  # User Based Prediction
print('User-User Similarity Based Predictor Created.')


print('Creating recommender..')
UB_Reco = SReco(songs_ordered)
UB_Reco.Add(UB_pred)
UB_Reco.Gamma = [1.0]
UB_Reco.tau = NumOfRecommendations
r2 = UB_Reco.RecommendToUsers(users[:100], u2s_ev)
print(len(r2))
save_recommendations(r2, "kaggle_songs.txt", "UserBasedResults.txt")

l_rec_songs_dic2 = dict()
for i, rlist in enumerate(r2):
    l_rec_songs_dic2[users[i]] = rlist

print(mAP_mod(users[:100],l_rec_songs_dic2,u2s_testing,30))
# Out:
# loading users in kaggle_users.txt
# default ordering by popularity
# loading unique users indexes
# song to users on year1_test_triplets_hidden.txt
# converting users to indices
# user to songs on year1_test_triplets_visible.txt
# Creating predictor..
# User-User Similarity Based Predictor Created.
# Creating recommender..
# 10] 992fea335363e87217e1b052fd7380b3fd7e35b4 w/ 51 songs
#  tot secs: 6.640214 (0.664021)
# 20] 7a1da2cfab87398a137441a85aee84793a376302 w/ 49 songs
#  tot secs: 13.126846 (0.656342)
# 30] 597c85c79b8dde655ec3fb8a7c41e3427d7f716f w/ 48 songs
#  tot secs: 19.547867 (0.651596)
# 40] dfadfaa39598cf760125439346d903ea0467e7fa w/ 48 songs
#  tot secs: 25.867864 (0.646697)
# 50] 3233c598c50f0ddbd351504e773cd51de79691db w/ 47 songs
#  tot secs: 32.110866 (0.642217)
# 60] 970fafbf218e788e97784de3d681f7486fe5376a w/ 47 songs
#  tot secs: 38.516567 (0.641943)
# 70] 126a1a844437af98ac07350e1e3dbec9681d5be4 w/ 46 songs
#  tot secs: 44.860546 (0.640865)
# 80] c51db436e58a0d44d8d6c171182254eaf0d136a4 w/ 46 songs
#  tot secs: 51.143459 (0.639293)
# 90] 03c89ca804a4c80a2ec64504ff2cdacc47d97d45 w/ 45 songs
#  tot secs: 57.565429 (0.639616)
# 100] 2d50e29337f17ef1521e32d2310acf3be51984b6 w/ 45 songs
#  tot secs: 64.181459 (0.641815)
# 100
# Loading song indices from kaggle_songs.txt
# Saving recommendations
# Ok.
# 0.07644111699192406

# %%
#3 Recommendations for all the users using UserBased Similarity
for user in l_rec_songs_dic2:
    print(f'Songs for User[{user}]:')
    for rsong in l_rec_songs_dic2[user][:3]:
        print(song_id_to_title[rsong])
# Out:
# Songs for User[7d90be8dfdbde170f036ce8a4b915440137cb11c]:
# Vim (Album Version)
# O.N.E. (XXXChange Remix)
# (The Symphony Of) Blase'
# Songs for User[016a24e91a72c159a5048ab1b9b2ba5ce761b526]:
# Sehr kosmisch
# Undo
# Secrets
# Songs for User[03ad93fdb01506ce205f4708decf8e4b1ae90fff]:
# Undo
# You're The One
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Songs for User[0f8308935bcbb9a1e04ebb7c4d41c037e5f23b90]:
# Undo
# You're The One
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Songs for User[2e424b28bff1f62a2dae22a918f09f9c30c06d1b]:
# Catch You Baby (Steve Pitron & Max Sanna Radio Edit)
# I Get Joy
# The Invisible Man
# Songs for User[d30e18323f15426c3cdc8585252ed34459916f51]:
# You're The One
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Revelry
# Songs for User[316110734d8da7478cc33237458814f770a9eb7a]:
# Undo
# Sehr kosmisch
# Revelry
# Songs for User[7e27789eae69bc946c51833c0b833a49c58ed9ed]:
# Jezebel
# Hang On To Your Love
# Your Love Is King
# Songs for User[9769ebffc543fa42b58daf6f52f8816abf5f408e]:
# Luz Dos Olhos
# Love And War (11/11/46) (Album Version)
# Coda
# Songs for User[992fea335363e87217e1b052fd7380b3fd7e35b4]:
# Times Like These
# Revolution 909
# Breakdown
# Songs for User[e08848e92427e9ef8add59a1264c484e1078d5a5]:
# Undo
# You're The One
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Songs for User[e99ef008f893efd071a7a77be6f1e8d23b962278]:
# Le Moulin
# Sleepyhead
# Moth's Wings
# Songs for User[1fb619ced83fb4f92d4098709d7331b30e5e691c]:
# You're The One
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Sehr kosmisch
# Songs for User[9b0f827c8bad0cf089b0d778307e1b390f463730]:
# Undo
# You're The One
# Sehr kosmisch
# Songs for User[ad4b2717e89766b66b96fe52a38736116e315874]:
# Dog Days Are Over (Radio Edit)
# Fireflies
# Hey_ Soul Sister
# Songs for User[b7bc5c9ea762079424d014c1b4e05e1d65d68861]:
# Sehr kosmisch
# Hey_ Soul Sister
# Secrets
# Songs for User[b976263ea6b444c431759549a75b3650c66183a6]:
# Undo
# Revelry
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Songs for User[ca885bed5d391ccc0fda84e8eb4441e005f68bcd]:
# Tacobel Canon
# Superstar (featuring Matthew Santos) (Album Version)
# Intruder Alert (feat. Sarah Green) (Explicit Album Version)
# Songs for User[6a41b6a2e27eff73509684bdfa13271b571e2e64]:
# Picture U & Me
# Superfreak
# Sway (Album Version)
# Songs for User[7a1da2cfab87398a137441a85aee84793a376302]:
# Sehr kosmisch
# Secrets
# Fireflies
# Songs for User[cdf02034d8a63dd8f4b4c22a5e7b225a37bdb844]:
# Sehr kosmisch
# Dog Days Are Over (Radio Edit)
# Secrets
# Songs for User[fd94f121ddfa8521f2348cb9863f0a7b475b7690]:
# Somebody To Love
# Stuck In The Moment
# U Smile
# Songs for User[0c210254fc2eaf598f3a1b68212d4202d91a9935]:
# Sehr kosmisch
# You're The One
# Revelry
# Songs for User[0f006f78b80e7a1f2767c8bdeecf9c81f2fdc78c]:
# Attention
# Old Enough (Featuring Ricky Skaggs and Ashley Monroe)
# Hold Up
# Songs for User[21a96fddf16490d907e44d0dfa11981ede0d96e9]:
# White Moth
# Messages
# Come As You Are
# Songs for User[2cc9422e11d2c7e3b0ab5aca3fa22308995ff15d]:
# Paradise City
# Master Of Puppets
# Eye Of The Tiger
# Songs for User[4759c3e074d8a6d1caeab6ca4a88c06384d42748]:
# Undo
# Revelry
# Sehr kosmisch
# Songs for User[531d1d0b66781028d346e0f0859713b982240382]:
# Undo
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Ain't Misbehavin
# Songs for User[5557cc213a706529adba8419eee285cfe9e43c24]:
# Elephant Gun
# Nantes
# Neon Bible
# Songs for User[597c85c79b8dde655ec3fb8a7c41e3427d7f716f]:
# Por Favor Señora
# Sehr kosmisch
# Sera Que Si
# Songs for User[5b3b7cd00e95e2680fac770b7e18c070bf02e527]:
# Undo
# You're The One
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Songs for User[5cebb084cfddab0dfd1e5ab5c3184b2e0c560786]:
# Tiger Mountain Peasant Song
# Baby
# Mykonos
# Songs for User[5dd9ca919c054bfa1deb7bb6945e85c153803d4c]:
# Sehr kosmisch
# Two Worlds Collide
# Dinosaur
# Songs for User[6e319c81e97184f63ab101e94b6d3222d672d5ff]:
# You're The One
# Undo
# West One (Shine On Me)
# Songs for User[8a463b7fe927c959e551be2efec5a7e1e0064929]:
# Neon
# Sick & Tired
# Waiting On The World To Change
# Songs for User[9cf0817fa7aaeb64882d7e51ba76be667c8d072c]:
# Sehr kosmisch
# Secrets
# You've Got The Love
# Songs for User[9daa6c7bda5ddabd68d04e678b3e52c30b9ab843]:
# The Downfall Of Us All
# Homesick
# I'm Made Of Wax_ Larry_ What Are You Made Of?
# Songs for User[cf2c73076560378d178b35264851b6999bdc9579]:
# You're The One
# Revelry
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Songs for User[d49babd1945ee325cdd3aaf152d6c76fccc0c04b]:
# I Gotta Feeling
# Sehr kosmisch
# OMG
# Songs for User[dfadfaa39598cf760125439346d903ea0467e7fa]:
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Sehr kosmisch
# Secrets
# Songs for User[ecd8e3aaf27af93873acff818f531f5c5d037dcb]:
# Mia
# Illuminati
# The Prize
# Songs for User[030915d79bddd3062aa433513ad36a943ab4152f]:
# Undo
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Tive Sim
# Songs for User[052213105f0428f006119159553425c07c239c97]:
# Sehr kosmisch
# Digital Love
# Somebody To Love
# Songs for User[1ba3904f06a1b49da7ec7f016b42c983042fd321]:
# Sao Paulo
# I Don't Know What I Can Save You From (Röyksopp Remix)
# Failure
# Songs for User[254e95345a32c795b049a8d7e9e6a11cfcfef42d]:
# Sehr kosmisch
# Undo
# Just Dance
# Songs for User[26b5dfef4cb37db6510a1d77076584811980092f]:
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Numb (Album Version)
# Everlong
# Songs for User[284124ef289e16c8746b081e92fec46d9eed5e78]:
# FU-GEE-LA
# Heaven
# Zealots
# Songs for User[2bf9c6c4c5189bd941d16116bf818f6c59d7f741]:
# Long Nights
# No Ceiling
# Hard Sun
# Songs for User[31a5f05c993b55420ff5b207fe64b193599215d3]:
# I'm On A Boat
# Boombox
# Sonne
# Songs for User[3233c598c50f0ddbd351504e773cd51de79691db]:
# My Name Is Jonas
# Love Is The Answer
# Why Bother?
# Songs for User[3f3984c156def23041b2bd2bfb8884f57f5f2d66]:
# Undo
# You're The One
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Songs for User[4288f4be2b04525b62ab8ba0fd6dd93f32f140e9]:
# Undo
# You're The One
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Songs for User[5a1a71a60eb86d499a9a3a885d375e66fab0338a]:
# Hypnopaedia
# The Way Things Go
# Rorol
# Songs for User[5e9d9185ca70601ff94ed404d3dc92bee6ec0e01]:
# Bitter Sweet Symphony
# Satisfaction
# The Funeral (Album Version)
# Songs for User[7a9bd2500f3baa32501b1c9ea9220b193f28b1fd]:
# No Ordinary Love
# Cold Desert
# Coleccionista De Canciones
# Songs for User[7b18741a2c0e8e2c9c09d2fa7b7d89c8dcb61ed6]:
# I Found A Whistle
# Freak Love
# Someone's Missing
# Songs for User[82d5c2935d6c31c3042630a23ff1dd51fa2e952c]:
# Undo
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# You're The One
# Songs for User[8c2fae6b21964abbf0e873a8a300410390c081a9]:
# Gold Guns Girls
# Collect Call
# Gimme Sympathy
# Songs for User[93e00920cb43b2f43c3eef4026597817fa11097d]:
# Undo
# Sehr kosmisch
# Invalid
# Songs for User[970fafbf218e788e97784de3d681f7486fe5376a]:
# Sehr kosmisch
# Drop The World
# In The End (Album Version)
# Songs for User[9edb7c549e06471e8da43bf484120044341f7bd4]:
# Représente
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Undo
# Songs for User[a0f6b8e2976781c862094eac5c3dfe65c1044908]:
# Undo
# You're The One
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Songs for User[b874455ac93a9d7128a096d45e8dd8ed75298a1f]:
# Resistance
# Sehr kosmisch
# Secrets
# Songs for User[c285a495ee23d5939f4cf3ac718cc1e3546130f3]:
# Catch You Baby (Steve Pitron & Max Sanna Radio Edit)
# Undo
# You're The One
# Songs for User[ca94838fb75b5a9403790364bd8a56e8df8b547a]:
# She Bop
# Sweet home Alabama
# Livin' On A Prayer
# Songs for User[d02a3c6c8dc8fc11c512024253a97693e544d90c]:
# Undo
# You're The One
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Songs for User[d5eb93b6ba887c9828abe9cbb7e02fa7f9cf2b08]:
# Sehr kosmisch
# Marry Me
# Dog Days Are Over (Radio Edit)
# Songs for User[e48ec63ed90a119eafe5338b18850ad2502e6910]:
# Revelry
# Tive Sim
# Ain't Misbehavin
# Songs for User[e8b69fea692deaa7ad925ba52fbcabbc4b4ed961]:
# Crumpshit
# Realize
# You're The One
# Songs for User[126a1a844437af98ac07350e1e3dbec9681d5be4]:
# Sway (Album Version)
# Dog Days Are Over (Radio Edit)
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Songs for User[13cee37ea2e198ce8354a962b118c1770db351d6]:
# Cupid Come
# Neon Bible
# Ocean Of Noise
# Songs for User[1883628f31fcf5793dbc0d6d6a97de6d7025b29f]:
# The Gift
# What They Found
# Marshall Examines His Carcass
# Songs for User[29b9a2bbe03bbc749926eb27374fd371a4504cda]:
# Stoppage Time
# Another One Rides The Bus
# Uncle Mountain (Album Version)
# Songs for User[44a7e35f9096a1b089d6c4a9824026792ad22ab7]:
# Taylor
# Run Me Down
# Lies
# Songs for User[6f0b83b30aa02aa6e211e7c26b6e5f3b69eed441]:
# Sehr kosmisch
# Secrets
# Fireflies
# Songs for User[8c8b8f3f729f8a95b5ad27bebd8ef63fc69fa92f]:
# Who Can Compare
# Rain
# Sehr kosmisch
# Songs for User[a4892375ecd9d837c01ae56f65c7e0c971cf6404]:
# I'm Good_ I'm Gone
# Hanging High
# Melodies & Desires
# Songs for User[bf628d66bd65a4287683183a1f4d55a5df722a2a]:
# In The End (Album Version)
# Have Faith In Me
# Given Up (Album Version)
# Songs for User[c4adbfad63abf742ce4e7831626c0dffbba594c1]:
# Sehr kosmisch
# You're The One
# Undo
# Songs for User[c51db436e58a0d44d8d6c171182254eaf0d136a4]:
# Undo
# You're The One
# Sehr kosmisch
# Songs for User[c75cf74cab428a4cba9b8679a5c0d2843caaf928]:
# Fireflies
# Use Somebody
# Somebody To Love
# Songs for User[cb5a3fd164ba01767a35a4311baaf5de47aa815b]:
# Undo
# You're The One
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Songs for User[cf9fdf97c554f55a5ee15573a8bc9ca9f93f8487]:
# Don de fluir
# Veneno
# No Pienses De Mas
# Songs for User[cff21116daa6af7719ed41e4b540feeaf5f31803]:
# Undo
# Secrets
# Dog Days Are Over (Radio Edit)
# Songs for User[dcc2873cbb96146e4187c2f7e785d690ecf42b65]:
# Sehr kosmisch
# Hey_ Soul Sister
# Secrets
# Songs for User[ef9f2f97aa9f72d4c18609e414a9077234c27119]:
# Just Like You
# Home
# I Hate Everything About You
# Songs for User[f148be1d392e400016ec4ef3610259d0c5851c5e]:
# Dog Days Are Over (Radio Edit)
# Cosmic Love
# Kiss With A Fist
# Songs for User[f3dbd374830a4ee7cca9f967a07b5bc91b3b5c52]:
# The Scientist
# Yellow
# Secrets
# Songs for User[01a85f046df67f633f93584e4304c2ba9ed69717]:
# Secrets
# Fireflies
# Undo
# Songs for User[03c89ca804a4c80a2ec64504ff2cdacc47d97d45]:
# Kaili
# Lalibela
# Found Out
# Songs for User[076f4ffd2d560d0c4c77049587d4b9a0a9f9d566]:
# Sehr kosmisch
# Undo
# You're The One
# Songs for User[0b505a2b01ab9f3aca17e6f56d78739a045482e0]:
# It's My Job To Keep Punk Rock Elite
# Time Honoured Tradition
# Flor Venenosa
# Songs for User[0ea17495115c4796365f24c15215da79749c6478]:
# Beautiful
# The Rider On The White Horse
# Here I Am
# Songs for User[208570bd10225df3b6d8320f80a4a6f4640f859e]:
# Undo
# Revelry
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Songs for User[2457a1423fbc83fd39f4dfcbcab73dc5a90ab7c5]:
# Sehr kosmisch
# I Gotta Feeling
# Billionaire [feat. Bruno Mars]  (Explicit Album Version)
# Songs for User[25ad9ea0366e4e39ac188266a73e4e643538108d]:
# Debajo del mar
# Bar Tacuba
# Why Worry
# Songs for User[2603699970dd851de605969efe7692025d781451]:
# Undo
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# Tive Sim
# Songs for User[2bcfb4744620a204cd7a1c562f58336846b17c5e]:
# FootShooter
# Planet Telex
# Red Right Ankle
# Songs for User[2cd5d5b6e63be5eb0b0236a3abe0507edf0f6570]:
# Patience
# Sehr kosmisch
# Paradise City
# Songs for User[2d50e29337f17ef1521e32d2310acf3be51984b6]:
# You're The One
# Secrets
# Revelry
